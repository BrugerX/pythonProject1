# %%
import LotDataPackage.ExtractorsAndTables as ent
import Browser as brwsr

# %%
lot_soup = brwsr.SeleniumBrowser.getAuctionSoup(85735881,True)
print(lot_soup is None)
# Out:
# Error occurred while getting the closed auction soup for 85735881:  Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF69C468152+13538]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF69C3F1E09+595497]
# 	(No symbol) [0x00007FF69C20E6CF]
# 	(No symbol) [0x00007FF69C252960]
# 	(No symbol) [0x00007FF69C252A1F]
# 	(No symbol) [0x00007FF69C28D627]
# 	(No symbol) [0x00007FF69C27203F]
# 	(No symbol) [0x00007FF69C248147]
# 	(No symbol) [0x00007FF69C28B1EE]
# 	(No symbol) [0x00007FF69C271C63]
# 	(No symbol) [0x00007FF69C24766E]
# 	(No symbol) [0x00007FF69C24683C]
# 	(No symbol) [0x00007FF69C247221]
# 	Microsoft::Applications::Events::EventProperty::to_string [0x00007FF69C6296F4+1099860]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF69C36D8FC+53532]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF69C360E25+1605]
# 	Microsoft::Applications::Events::EventProperty::to_string [0x00007FF69C628685+1095653]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF69C3FC981+27777]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF69C3F6D04+4100]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF69C3F6E3B+4411]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF69C3ECFC0+575456]
# 	BaseThreadInitThunk [0x00007FFC25D9257D+29]
# 	RtlUserThreadStart [0x00007FFC276CAF28+40]
#
#  Will try to get the active soup
# False
# Error occurred while getting the closed auction soup for 85735881:  Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF69C468152+13538]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF69C3F1E09+595497]
# 	(No symbol) [0x00007FF69C20E6CF]
# 	(No symbol) [0x00007FF69C252960]
# 	(No symbol) [0x00007FF69C252A1F]
# 	(No symbol) [0x00007FF69C28D627]
# 	(No symbol) [0x00007FF69C27203F]
# 	(No symbol) [0x00007FF69C248147]
# 	(No symbol) [0x00007FF69C28B1EE]
# 	(No symbol) [0x00007FF69C271C63]
# 	(No symbol) [0x00007FF69C24766E]
# 	(No symbol) [0x00007FF69C24683C]
# 	(No symbol) [0x00007FF69C247221]
# 	Microsoft::Applications::Events::EventProperty::to_string [0x00007FF69C6296F4+1099860]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF69C36D8FC+53532]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF69C360E25+1605]
# 	Microsoft::Applications::Events::EventProperty::to_string [0x00007FF69C628685+1095653]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF69C3FC981+27777]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF69C3F6D04+4100]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00007FF69C3F6E3B+4411]
# 	Microsoft::Applications::Events::EventProperty::~EventProperty [0x00007FF69C3ECFC0+575456]
# 	BaseThreadInitThunk [0x00007FFC25D9257D+29]
# 	RtlUserThreadStart [0x00007FFC276CAF28+40]
#
#  Will try to get the active soup
# False

# %%
lot_soup
# Out:
# <html class="has-js" lang="en"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><meta content="@catawiki" name="twitter:creator"/><meta content="en" property="og:locale"/><title>Necklace - 18 kt. Yellow gold - Catawiki</title><meta content="index,follow" name="robots"/><meta content="18k yellow gold necklace
# Quality: This piece of jewelry has been tested for gold content by our expert and found to be authentic. For your impression, look at the photos.
#
# Object Type: Necklace
#
# Gender: Unisex
# Material: Yellow gold
# Material Title: 18K
# Length 45.00 cm x 0.30 to 0.50 cm approximately
# Total weight: 12.66 g
# Condition: Excellent condition
#
# Insured shipping with tracking number.
# They will be sent registered and insured by DHL. Buyers outside the EU must take into account the VAT and customs duties they have to pay.
# Buyers subject to customs, if they opt for the right of withdrawal, will be required to pay customs duties also for the return of the lot to the seller." name="description"/><link href="https://www.catawiki.com/en/l/86022247-necklace-18-kt-yellow-gold" hreflang="en" rel="alternate"/><link href="https://www.catawiki.com/nl/l/86022247-halsketting-18-karaat-geel-goud" hreflang="nl" rel="alternate"/><link href="https://www.catawiki.com/de/l/86022247-necklace-18-kt-yellow-gold" hreflang="de" rel="alternate"/><link href="https://www.catawiki.com/fr/l/86022247-collier-18-carats-or-jaune" hreflang="fr" rel="alternate"/><link href="https://www.catawiki.com/it/l/86022247-collana-18-carati-oro-giallo" hreflang="it" rel="alternate"/><link href="https://www.catawiki.com/es/l/86022247-collar-18-quilates-oro-amarillo" hreflang="es" rel="alternate"/><link href="https://www.catawiki.com/zh-Hans/l/86022247-necklace-18-kt-yellow-gold" hreflang="zh-Hans" rel="alternate"/><link href="https://www.catawiki.com/zh-Hant/l/86022247-necklace-18-kt-yellow-gold" hreflang="zh-Hant" rel="alternate"/><link href="https://www.catawiki.com/pt/l/86022247-colar-18-k-ouro-amarelo" hreflang="pt" rel="alternate"/><link href="https://www.catawiki.com/da/l/86022247-halskaede-18-kraat-gulguld" hreflang="da" rel="alternate"/><link href="https://www.catawiki.com/sv/l/86022247-halsband-18-kt-gult-guld" hreflang="sv" rel="alternate"/><link href="https://www.catawiki.com/no/l/86022247-halskjede-18-karat-gull" hreflang="no" rel="alternate"/><link href="https://www.catawiki.com/pl/l/86022247-naszyjnik-18-karatowe-zolte-zloto" hreflang="pl" rel="alternate"/><link href="https://www.catawiki.com/el/l/86022247-18" hreflang="el" rel="alternate"/><link href="https://www.catawiki.com/hu/l/86022247-nyaklanc-18-kt-sarga-arany" hreflang="hu" rel="alternate"/><link href="https://www.catawiki.com/ro/l/86022247-colier-18-ct-aur-galben" hreflang="ro" rel="alternate"/><link href="https://www.catawiki.com/fi/l/86022247-kaulakoru-18-kt-keltakulta" hreflang="fi" rel="alternate"/><meta content="summary_large_image" name="twitter:card"/><meta content="@Catawiki" name="twitter:site"/><meta content="238226522900020" property="fb:app_id"/><meta content="Necklace - 18 kt. Yellow gold" property="og:title"/><meta content="18k yellow gold necklace
# Quality: This piece of jewelry has been tested for gold content by our expert and found to be authentic. For your impression, look at the photos.
#
# Object Type: Necklace
#
# Gender: Unisex
# Material: Yellow gold
# Material Title: 18K
# Length 45.00 cm x 0.30 to 0.50 cm approximately
# Total weight: 12.66 g
# Condition: Excellent condition
#
# Insured shipping with tracking number.
# They will be sent registered and insured by DHL. Buyers outside the EU must take into account the VAT and customs duties they have to pay.
# Buyers subject to customs, if they opt for the right of withdrawal, will be required to pay customs duties also for the return of the lot to the seller." property="og:description"/><meta content="https://www.catawiki.com/en/l/86022247-necklace-18-kt-yellow-gold" property="og:url"/><meta content="product" property="og:type"/><meta content="https://assets.catawiki.nl/assets/2024/5/25/e/4/4/e44410b0-25e3-4d1c-bc86-e8d22c6bc49f.jpg" property="og:image"/><meta content="Catawiki" property="og:site_name"/><link href="https://www.catawiki.com/en/l/86022247-necklace-18-kt-yellow-gold" rel="canonical"/><meta content="34" name="next-head-count"/><script async="" src="/UZlkr2ZV/init.js"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-M822ES1M07&amp;l=dataLayer&amp;cx=c" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-N14JY514FR&amp;l=dataLayer&amp;cx=c" type="text/javascript"></script><script async="" src="//www.googletagmanager.com/gtm.js?id=GTM-N3WK28"></script><script>window.dataLayer = window.dataLayer || [];dataLayer.push({"next":1,"BiddingEndTime":"2024-07-13T12:00:00Z","BiddingStartTime":"2024-07-05T16:00:00Z","ContentGroup":"Auctions","PageType":"ProductPage","ThemedOrRegularAuction":"Regular","auction_best_name":"Women's Jewellery Auction","auction_group":null,"auction_group_en":null,"auction_group_id":null,"opportunity_lot":null,"auction_id":995687,"auction_name":"Women's Jewellery Auction","auction_theme":null,"auction_theme_id":null,"auction_type_family_id":null,"auction_type_family_name":"","auction_type_id":1023,"category_L0_id":714,"category_L0_name":"Jewellery & Precious Stones","category_L1_id":313,"category_L1_name":"Jewellery","category_L2_id":1429,"category_L2_name":"Women's Jewellery","criteo_page_type":"ProductPage","lot_id":86022247,"lot_state":"bidding_started","product_id":86022247,"promo_lot_ids":86022247});</script><script>document.documentElement.className += ' has-js';</script><meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, user-scalable=no, initial-scale=1.0, minimal-ui" name="viewport"/>
# <meta content="en" name="locale-rfc4646"/>
# <meta content="app-id=926272969" name="apple-itunes-app"/>
# <link href="//cdn.catawiki.net/assets/shared-assets/ui/v2/icons/favicon-4def9970acc4196d1e619785999fe8586b680924d26b481adee2e2c95b68e1f2.ico" rel="shortcut icon"/>
# <link href="//cdn.catawiki.net/assets/shared-assets/ui/v2/icons/favicon-16x16-7a45ceffdde6bd88effc549c62ac478dc11b67c302099b1b74b27ee32a73a861.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="//cdn.catawiki.net/assets/shared-assets/ui/v2/icons/favicon-32x32-a2ac7fbffbf804da3f281a674f49e2654adb0257bb26c2221233a6076a42cb35.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="//cdn.catawiki.net/assets/shared-assets/ui/v2/icons/apple-touch-icon-b13ce911e07ac90e25d8cdabcc464d6b2dc80ef0dc07f29894c80835594e83c2.png" rel="apple-touch-icon" sizes="180x180"/>
# <link color="#0033ff" href="//cdn.catawiki.net/assets/shared-assets/ui/v2/icons/safari-pinned-tab-v1-f117b130971240419fea7a257ddc9356578464dc1b5806301afb1e503d83b277.svg" rel="mask-icon"/>
# <link crossorigin="anonymous" href="//cdn.catawiki.net/assets/shared-assets/ui/v2/webpack/css/msHeader.0cbb33b5d938d3f59be0.css" media="all" rel="stylesheet"/>
# <script>
#  window.CW_ENVIRONMENT_ASSETS = {
#  STAGE: "production",
#  ASSETS_URL: "https://cdn.catawiki.net/assets/shared-assets/ui/v2/webpack/",
#  AB_SMARTLY_ENDPOINT: "https://catawiki.absmartly.io/v1",
#  AB_SMARTLY_API_KEY: "auYSRnUD-CAC9jHXxEmopM30CvFWSCrbZlDipk96JvHxEbSXZBaEMUeBNFjCz6Oo",
#  };
#
#  // Loading the Kustomer chat SDK credentials
#  window.KUSTOMER = {
#  defaultAssistantId: "6315eb8a0ceb41561a017a45",
#  token: "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..QmJC7v6_PLFOgykyYCBbxS_bcebsGDwPJroXWZESXZ8",
#  };
# </script>
# <link crossorigin="anonymous" href="//cdn.catawiki.net/assets/shared-assets/ui/v2/webpack/css/msHeader.0cbb33b5d938d3f59be0.css" media="all" rel="stylesheet"/>
# <script crossorigin="anonymous" src="//cdn.catawiki.net/assets/shared-assets/ui/v2/webpack/js/vendor.d6f14310c99d161e705a.js"></script>
# <script crossorigin="anonymous" src="//cdn.catawiki.net/assets/shared-assets/ui/v2/webpack/js/msGtm.1ca500abe2d8091fd0e4.js"></script>
# <noscript>
# <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-N3WK28" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <script>
#  (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#  new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#  j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#  '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#  })(window,document,'script','dataLayer',"GTM-N3WK28");
# </script>
# <script data-nscript="beforeInteractive" id="ld_schema" type="application/ld+json">{"@context":"https://schema.org","@type":"Product","name":"Necklace - 18 kt. Yellow gold","image":["https://assets.catawiki.nl/assets/2024/5/25/e/4/4/thumb5_e44410b0-25e3-4d1c-bc86-e8d22c6bc49f.jpg","https://assets.catawiki.nl/assets/2024/5/25/e/4/4/e44410b0-25e3-4d1c-bc86-e8d22c6bc49f.jpg"],"description":"18k yellow gold necklace\nQuality: This piece of jewelry has been tested for gold content by our expert and found to be authentic. For your impression, look at the photos.\n\nObject Type: Necklace\n\nGender: Unisex\nMaterial: Yellow gold\nMaterial Title: 18K\nLength 45.00 cm x 0.30 to 0.50 cm approximately\nTotal weight: 12.66 g\nCondition: Excellent condition\n\nInsured shipping with tracking number.\nThey will be sent registered and insured by DHL. Buyers outside the EU must take into account the VAT and customs duties they have to pay.\nBuyers subject to customs, if they opt for the right of withdrawal, will be required to pay customs duties also for the return of the lot to the seller.","aggregateRating":{"@type":"AggregateRating","ratingValue":99.78,"reviewCount":11262,"bestRating":100}}</script><link as="style" href="/assets/buyer_ui/_next/static/css/03b74c46157c5413.css" rel="preload"/><link data-n-g="" href="/assets/buyer_ui/_next/static/css/03b74c46157c5413.css" rel="stylesheet"/><link as="style" href="/assets/buyer_ui/_next/static/css/b41bce945af2f6be.css" rel="preload"/><link data-n-p="" href="/assets/buyer_ui/_next/static/css/b41bce945af2f6be.css" rel="stylesheet"/><link as="style" href="/assets/buyer_ui/_next/static/css/3719df33801bac57.css" rel="preload"/><link data-n-p="" href="/assets/buyer_ui/_next/static/css/3719df33801bac57.css" rel="stylesheet"/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="/assets/buyer_ui/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js"></script><script defer="" src="/assets/buyer_ui/_next/static/chunks/webpack-419b42f975bee250.js"></script><script defer="" src="/assets/buyer_ui/_next/static/chunks/framework-eae1dab60e375b5f.js"></script><script defer="" src="/assets/buyer_ui/_next/static/chunks/main-20fb64b90b6891be.js"></script><script defer="" src="/assets/buyer_ui/_next/static/chunks/pages/_app-1a2e0d8092578b0b.js"></script><script defer="" src="/assets/buyer_ui/_next/static/chunks/ea88be26-43b75960b55a0567.js"></script><script defer="" src="/assets/buyer_ui/_next/static/chunks/3998-b5cfd1a4bb7201c8.js"></script><script defer="" src="/assets/buyer_ui/_next/static/chunks/9256-df996fbe8a6ba4a5.js"></script><script defer="" src="/assets/buyer_ui/_next/static/chunks/1248-63876afe6f00a345.js"></script><script defer="" src="/assets/buyer_ui/_next/static/chunks/9260-15410fb5b1065f29.js"></script><script defer="" src="/assets/buyer_ui/_next/static/chunks/6411-9adbc48e9657248c.js"></script><script defer="" src="/assets/buyer_ui/_next/static/chunks/107-8a84a5001ef12f1c.js"></script><script defer="" src="/assets/buyer_ui/_next/static/chunks/2411-59399976bd34151b.js"></script><script defer="" src="/assets/buyer_ui/_next/static/chunks/5516-4c5ead681981b3d3.js"></script><script defer="" src="/assets/buyer_ui/_next/static/chunks/5053-2e374caa4f4658ab.js"></script><script defer="" src="/assets/buyer_ui/_next/static/chunks/6743-9d059b7e3196ed50.js"></script><script defer="" src="/assets/buyer_ui/_next/static/chunks/9009-7a3c2b815e1cac74.js"></script><script defer="" src="/assets/buyer_ui/_next/static/chunks/2803-8e16787fb444839a.js"></script><script defer="" src="/assets/buyer_ui/_next/static/chunks/5368-1dacc4dd39198436.js"></script><script defer="" src="/assets/buyer_ui/_next/static/chunks/6606-fb5cb94f4b090c3f.js"></script><script defer="" src="/assets/buyer_ui/_next/static/chunks/5504-7f9dfcff044ceb16.js"></script><script defer="" src="/assets/buyer_ui/_next/static/chunks/9777-5031643ee2efdbd0.js"></script><script defer="" src="/assets/buyer_ui/_next/static/chunks/4021-42fa0a726922555c.js" ...
# <header class="c-header">
# <div class="c-header__main ab_snd_web_sticky_filters">
# <div class="c-header__wrapper u-wrapper">
# <div class="c-header__logo c-header__part-of-categories">
# <a aria-label="homepage" href="//www.catawiki.com/en/"><div class="c-header__logo__image c-header__logo__image__standard"></div>
# </a></div>
# <div class="c-header__categories-popover c-header__part-of-categories" data-loaded="true" data-props='{"title":"Categories"}' data-react-component-assets="CategoriesPopover"><div class="c-header__categories-popover-link-wrapper"><a class="c-header__categories-popover-link c-link main no-underline u-typography-h7">Categories</a></div></div>
# <div class="c-header__search__main-wrapper c-header__part-of-categories">
# <div class="c-header__search u-hide-print">
# <form action="" data-loaded="true" data-props='{"placeholder":"Search for brand, model, artist...","helpCenterPlaceholder":"Search for help articles...","auctionsHeading":"Related Auctions","collectionsHeading":"Related collections","recentSearchesHeading":"Recent searches","savedSearchesHeading":"Saved searches ","clearLabel":"Clear","undoLabel":"Undo","searchesClearedMessage":"Searches cleared","categoriesHeading":"Categories","manageSearchLabel":"Manage searches","signinToSeeSavedSearcesLabel":"&lt;a href=\"%{link}\"&gt;Sign in&lt;/a&gt; to see searches you saved"}' data-react-component-assets="Search"><div class="c-search-field"><div class="c-search-field__back-header"><button class="c-button-template u-cursor-pointer c-button__container c-button--tertiary u-color-primary u-typography-h7 c-search-field__back-button" data-testid="back-button" type="button"><span class="c-button__overlay c-button__overlay--tertiary"></span><span class="c-button__content"><svg aria-hidden="true" class="c-button__icon c-button__icon--tertiary u-icon-m" fill="none" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M13.59 6 15 7.41 10.42 12 15 16.59 13.59 18l-6-6z" fill="currentColor"></path></svg></span></button></div><div><div class="c-text-field c-text-field--normal c-search-field__field js-search-autocomplete"><div class="c-text-field__wrapper"><div class="c-text-field__prefix u-color-dark-gray u-cursor-pointer" data-testid="text-field-prefix"><button aria-label="Search" class="c-button-template u-cursor-pointer c-button__container c-button--tertiary u-color-brand u-typography-h7" type="button"><span class="c-button__overlay c-button__overlay--tertiary"></span><span class="c-button__content"><svg aria-hidden="true" class="c-button__icon c-button__icon--tertiary u-icon-m" fill="none" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="m17.9 16.5 5.1 5.1.7.7-1.4 1.4-.7-.7-5.1-5.1a9.7 9.7 0 0 1-6 2.1A9.6 9.6 0 0 1 1 10.5 9.6 9.6 0 0 1 10.5 1a9.6 9.6 0 0 1 9.5 9.5 9.7 9.7 0 0 1-2.1 6M10.5 3A7.6 7.6 0 0 0 3 10.5a7.6 7.6 0 0 0 7.5 7.5 7.6 7.6 0 0 0 7.5-7.5A7.6 7.6 0 0 0 10.5 3" fill="currentColor" fill-rule="evenodd"></path></svg></span></button></div><div class="c-text-field__input-wrapper label__wrapper"><input aria-expanded="false" aria-haspopup="listbox" autocapitalize="off" autocomplete="off" class="c-text-field__input c-search-field__input" data-auctions-heading="Related Auctions" data-testid="search-field" id="field:r2:" placeholder="Search for brand, model, artist..." role="combobox" type="search" value=""/></div></div></div></div></div></form>
# </div>
# </div>
# <nav class="c-header__links c-header__part-of-categories u-hide-print">
# <div class="c-header__links u-typography-h7 u-color-title-text">
# <div class="c-header__links__sell u-hide-s">
# <div class="c-header__links__normal-link">
# <a class="header-sell c-link main no-underline" href="//www.catawiki.com/en/seller/lot">Sell</a>
# </div>
# </div>
# <div class="c-header__links__guides u-hide-s">
# <div class="c-header__links__normal-link">
# <a class="c-link main no-underline" href="//www.catawiki.com/en/help">Help</a>
# </div>
# </div>
# <div class="c-header__links__favourite u-hide-s">
# <a aria-label="Favourites" href="//www.catawiki.com/en/veiling/favorites" id="favourite-link-header"><svg class="u-svg" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M18.4 1.1c-2.306-.488-4.698.272-6.3 2h-.2c-1.602-1.728-3.994-2.488-6.3-2C2.688 1.679.473 4.055.1 7c-.336 2.187.366 4.405 1.9 6l10 10 10-10c1.534-1.595 2.236-3.813 1.9-6-.373-2.945-2.588-5.321-5.5-5.9zm2.1 10.4L12 20l-8.6-8.4c-1.136-1.16-1.622-2.809-1.3-4.4.313-2.013 1.816-3.635 3.8-4.1 2.056-.486 4.192.4 5.3 2.2.189.252.485.4.8.4.315 0 .611-.148.8-.4 1.147-1.752 3.25-2.624 5.3-2.2 1.968.426 3.476 2.012 3.8 4 .316 1.61-.212 3.269-1.4 4.4z" fill="#03F"></path>
# </svg>
# </a></div>
# <div class="u-hide-print u-hide-s">
# <div data-loaded="true" data-props='{"isMobile":false,"t":{"dropdownTitle":"Updates","emptyStateTitle":"No updates","emptyStateBody":"Check back soon for the latest updates.","errorTitle":"Something went wrong. Please try again later","shortTimeFormat":"%d %b %H:%M"}}' data-react-component-assets="Notifications"></div>
# </div>
# <div data-loaded="true" data-props='{"mainLinks":{"exploreInterests":{"myFavoriteLots":{"name":"Favourite objects","url":"//www.catawiki.com/en/interests/objects"},"myBids":{"name":"Bids","url":"//www.catawiki.com/en/interests/objects/?sort_by=bids_first"},"orders":{"name":"Orders","url":"//www.catawiki.com/en/f/buyer/orders"},"myFollowedAuctions":{"name":"Followed auctions","url":"//www.catawiki.com/en/interests/following/auctions"},"mySearchAlerts":{"name":"Saved searches","url":"//www.catawiki.com/en/interests/searches"},"myCollections":{"name":"Collections I follow","url":"//www.catawiki.com/en/interests/following/collections"},"offers":{"name":"Offers","url":"//www.catawiki.com/en/interests/offers"}},"sell":{"sellerDashboard":{"name":"Sales overview","url":"//www.catawiki.com/en/seller/dashboard"},"lotsInAuction":{"name":"In auction","url":"//www.catawiki.com/en/seller/lots/live"},"myOfferedLots":{"name":"Submissions","url":"//www.catawiki.com/en/seller/lots"},"mySoldLots":{"name":"Sold","url":"//www.catawiki.com/en/f/seller/orders"},"unsoldLots":{"name":"Not sold","url":"//www.catawiki.com/en/seller/lots/unsold"},"payments":{"name":"Payments","url":"//www.catawiki.com/en/f/seller/payments"},"submitYourItem":{"name":"Submit your item","url":"//www.catawiki.com/en/seller/lot"},"sellWithUs":{"name":"Sell with us","url":"//www.catawiki.com/en/seller/register"},"sellerOverview":{"name":"Overview","url":"//www.catawiki.com/en/v/dashboard"},"sellerAnalytics":{"name":"Analytics","url":"//www.catawiki.com/en/v/analytics"}},"account":{"settings":{"name":"Settings","url":"//www.catawiki.com/en/accounts/settings/account"},"myMessages":{"name":"Messages","url":"//www.catawiki.com/en/f/conversations"},"help":{"name":"Help","url":"//www.catawiki.com/en/help"}}},"verifyLink":{"name":"Complete your profile","url":"//www.catawiki.com/en/accounts/settings/verifications"},"logoutLink":{"name":"Sign out","url":"//www.catawiki.com/en/user/logout"},"homeLink":{"name":"Switch to Catawiki for buyers","url":"//www.catawiki.com/en/"},"sellerSideLink":{"name":"Switch to Catawiki for sellers","url":"//www.catawiki.com/en/v/dashboard"},"translations":{"explore":"Explore","sell":"Sell","account":"Account","myCatawiki":"My Catawiki","verifyDescription":"Complete your registration and get started","userGreeting":"Hi {first_name}","anErrorHasOccurred":"An error has occurred. Please try again."}}' data-react-component-assets="UserMenu"></div>
# <div class="c-header__links__user-not-logged-in">
# <div class="c-header__links__popup u-hide-m u-hide-l">
# <div class="c-header__links__sign-in u-text-center u-font-size-s">
# <div data-loaded="true" data-props="{&quot;t&quot;:{&quot;email&quot;:&quot;Email address&quot;,&quot;googleButton&quot;:&quot;Continue with Google&quot;,&quot;continueWith&quot;:&quot;Continue with&quot;,&quot;facebookButton&quot;:&quot;Continue with Facebook&quot;,&quot;appleButton&quot;:&quot;Continue with Apple&quot;,&quot;login&quot;:&quot;Sign in&quot;,&quot;register&quot;:&quot;Register&quot;,&quot;loginWith&quot;:&quot;Sign in with&quot;,&quot;or&quot;:&quot;or&quot;,&quot;password&quot;:&quot;Password&quot;,&quot;registerButton&quot;:&quot;Create account&quot;,&quot;registerPlaceYourBidsHead&quot;:&quot;Place your bids on any of over 75,000 exceptional items auctioned every week&quot;,&quot;signInOrCreateAnAccount&quot;:&quot;Sign in or create an account&quot;,&quot;userPasswordLost&quot;:&quot;Forgotten your password?&quot;,&quot;userRememberMe&quot;:&quot;Remember me&quot;,&quot;welcomeBack&quot;:&quot;Welcome back!&quot;,&quot;enterNewPassword&quot;:&quot;Enter your new password&quot;,&quot;everyWeekObjectsAmount&quot;:&quot;Explore your passions and discover new ones. Over 75,000 new objects are added every week.&quot;,&quot;minPasswordRequirement&quot;:&quot;At least 8 characters, one capital letter, one lower case letter, one number and one special character&quot;,&quot;passwordResetLinkWillBeSent&quot;:&quot;We’ll email you a link to reset your password&quot;,&quot;passwordResetLinkSend&quot;:&quot;Send reset link&quot;,&quot;passwordResetLinkHasBeenSent&quot;:&quot;A link to reset your password was sent to %{email}&quot;,&quot;passwordValidationMinimalLength&quot;:&quot;Min 8 characters&quot;,&quot;passwordValidationDigitsAmount&quot;:&quot;Min one number&quot;,&quot;passwordValidationSpecialAmount&quot;:&quot;Min one special character&quot;,&quot;passwordValidationUpperAmount&quot;:&quot;Min one capital letter&quot;,&quot;passwordValidationLowerAmount&quot;:&quot;Min one lower case letter&quot;,&quot;firstName&quot;:&quot;First name&quot;,&quot;lastName&quot;:&quot;Last name&quot;,&quot;acceptConditions&quot;:&quot;By creating an account, you agree to our %{user_conditions} and acknowledge our %{privacy_policy}. Depending on how you use Catawiki, we may send you promotional emails. See our Privacy Policy for more info or to opt-out.&quot;,&quot;agreeAndContinue&quot;:&quot;Agree and continue&quot;,&quot;privacyPolicy&quot;:&quot;Privacy Policy&quot;,&quot;userAgreement&quot;:&quot;Terms of Use&quot;,&quot;generalError&quot;:&quot;Something went wrong, please try again later.&quot;,&quot;newPasswordNotCorrect&quot;:&quot;Make sure your new password is at least 8 characters and contains at least 1 number&quot;,&quot;required&quot;:&quot;This field is required&quot;,&quot;formIsInvalid&quot;:&quot;Please check and adjust your info.&quot;,&quot;userOnboardingUnsavedDataWarningMessage&quot;:&quot;Are you sure you want to exit? You can always log in and complete your profile later to start bidding. Press OK to exit.&quot;,&quot;maxCountCharacters&quot;:&quot;Max %{count} characters&quot;,&quot;enterYourHouseNumberOrFullStop&quot;:&quot;Enter your house number. If you don’t have one, enter a full stop (.)&quot;,&quot;back&quot;:&quot;Back&quot;,&quot;close&quot;:&quot;Close&quot;,&quot;open&quot;:&quot;Open&quot;,&quot;resetPassword&quot;:&quot;Reset your password&quot;,&quot;change&quot;:&quot;Change&quot;,&quot;country&quot;:&quot;Country&quot;,&quot;continue&quot;:&quot;Continue&quot;,&quot;phoneNumber&quot;:&quot;Phone number&quot;,&quot;countries&quot;:{&quot;ad&quot;:&quot;Andorra&quot;,&quot;at&quot;:&quot;Austria&quot;,&quot;be&quot;:&quot;Belgium&quot;,&quot;bg&quot;:&quot;Bulgaria&quot;,&quot;cn&quot;:&quot;China&quot;,&quot;cy&quot;:&quot;Cyprus&quot;,&quot;hr&quot;:&quot;Croatia&quot;,&quot;cz&quot;:&quot;Czech Republic&quot;,&quot;dk&quot;:&quot;Denmark&quot;,&quot;ee&quot;:&quot;Estonia&quot;,&quot;fi&quot;:&quot;Finland&quot;,&quot;fr&quot;:&quot;France&quot;,&quot;de&quot;:&quot;Germany&quot;,&quot;g ...
# <div class="c-header__links__new-user">
# New user?
# <a class="c-link underline js-create-account-btn" href="#modal__register">Create a free account</a>
# </div>
# </div>
# </div>
# <div class="u-hide-s">
# <div data-loaded="true" data-props="{&quot;t&quot;:{&quot;email&quot;:&quot;Email address&quot;,&quot;googleButton&quot;:&quot;Continue with Google&quot;,&quot;continueWith&quot;:&quot;Continue with&quot;,&quot;facebookButton&quot;:&quot;Continue with Facebook&quot;,&quot;appleButton&quot;:&quot;Continue with Apple&quot;,&quot;login&quot;:&quot;Sign in&quot;,&quot;register&quot;:&quot;Register&quot;,&quot;loginWith&quot;:&quot;Sign in with&quot;,&quot;or&quot;:&quot;or&quot;,&quot;password&quot;:&quot;Password&quot;,&quot;registerButton&quot;:&quot;Create account&quot;,&quot;registerPlaceYourBidsHead&quot;:&quot;Place your bids on any of over 75,000 exceptional items auctioned every week&quot;,&quot;signInOrCreateAnAccount&quot;:&quot;Sign in or create an account&quot;,&quot;userPasswordLost&quot;:&quot;Forgotten your password?&quot;,&quot;userRememberMe&quot;:&quot;Remember me&quot;,&quot;welcomeBack&quot;:&quot;Welcome back!&quot;,&quot;enterNewPassword&quot;:&quot;Enter your new password&quot;,&quot;everyWeekObjectsAmount&quot;:&quot;Explore your passions and discover new ones. Over 75,000 new objects are added every week.&quot;,&quot;minPasswordRequirement&quot;:&quot;At least 8 characters, one capital letter, one lower case letter, one number and one special character&quot;,&quot;passwordResetLinkWillBeSent&quot;:&quot;We’ll email you a link to reset your password&quot;,&quot;passwordResetLinkSend&quot;:&quot;Send reset link&quot;,&quot;passwordResetLinkHasBeenSent&quot;:&quot;A link to reset your password was sent to %{email}&quot;,&quot;passwordValidationMinimalLength&quot;:&quot;Min 8 characters&quot;,&quot;passwordValidationDigitsAmount&quot;:&quot;Min one number&quot;,&quot;passwordValidationSpecialAmount&quot;:&quot;Min one special character&quot;,&quot;passwordValidationUpperAmount&quot;:&quot;Min one capital letter&quot;,&quot;passwordValidationLowerAmount&quot;:&quot;Min one lower case letter&quot;,&quot;firstName&quot;:&quot;First name&quot;,&quot;lastName&quot;:&quot;Last name&quot;,&quot;acceptConditions&quot;:&quot;By creating an account, you agree to our %{user_conditions} and acknowledge our %{privacy_policy}. Depending on how you use Catawiki, we may send you promotional emails. See our Privacy Policy for more info or to opt-out.&quot;,&quot;agreeAndContinue&quot;:&quot;Agree and continue&quot;,&quot;privacyPolicy&quot;:&quot;Privacy Policy&quot;,&quot;userAgreement&quot;:&quot;Terms of Use&quot;,&quot;generalError&quot;:&quot;Something went wrong, please try again later.&quot;,&quot;newPasswordNotCorrect&quot;:&quot;Make sure your new password is at least 8 characters and contains at least 1 number&quot;,&quot;required&quot;:&quot;This field is required&quot;,&quot;formIsInvalid&quot;:&quot;Please check and adjust your info.&quot;,&quot;userOnboardingUnsavedDataWarningMessage&quot;:&quot;Are you sure you want to exit? You can always log in and complete your profile later to start bidding. Press OK to exit.&quot;,&quot;maxCountCharacters&quot;:&quot;Max %{count} characters&quot;,&quot;enterYourHouseNumberOrFullStop&quot;:&quot;Enter your house number. If you don’t have one, enter a full stop (.)&quot;,&quot;back&quot;:&quot;Back&quot;,&quot;close&quot;:&quot;Close&quot;,&quot;open&quot;:&quot;Open&quot;,&quot;resetPassword&quot;:&quot;Reset your password&quot;,&quot;change&quot;:&quot;Change&quot;,&quot;country&quot;:&quot;Country&quot;,&quot;continue&quot;:&quot;Continue&quot;,&quot;phoneNumber&quot;:&quot;Phone number&quot;,&quot;countries&quot;:{&quot;ad&quot;:&quot;Andorra&quot;,&quot;at&quot;:&quot;Austria&quot;,&quot;be&quot;:&quot;Belgium&quot;,&quot;bg&quot;:&quot;Bulgaria&quot;,&quot;cn&quot;:&quot;China&quot;,&quot;cy&quot;:&quot;Cyprus&quot;,&quot;hr&quot;:&quot;Croatia&quot;,&quot;cz&quot;:&quot;Czech Republic&quot;,&quot;dk&quot;:&quot;Denmark&quot;,&quot;ee&quot;:&quot;Estonia&quot;,&quot;fi&quot;:&quot;Finland&quot;,&quot;fr&quot;:&quot;France&quot;,&quot;de&quot;:&quot;Germany&quot;,&quot;g ...
# </div>
# </div>
# </div>
# </nav>
# <div class="c_header__mobile_nav c-header__part-of-categories" data-loaded="true" data-props='{"login_url":"//www.catawiki.com/en/accounts/login","user_favorites_link":"//www.catawiki.com/en/veiling/favorites","hide_search":false,"hide_favorites":false,"t":{"dropdownTitle":"Updates","emptyStateTitle":"No updates","emptyStateBody":"Check back soon for the latest updates.","errorTitle":"Something went wrong. Please try again later","shortTimeFormat":"%d %b %H:%M"},"is_seller_nav":false}' data-react-component-assets="MobileNavigation" style="height: 100%; display:flex"><div class="c-header__mobile-nav u-hide-m u-hide-l u-hide-print u-flex u-flex--align-items-center"><button class="c-button-template u-cursor-pointer c-button__container c-button--tertiary u-color-brand u-typography-h7 c-header__mobile-nav__item c-header__mobile-nav__search"><span class="c-button__overlay c-button__overlay--tertiary"></span><span class="c-button__content"><svg aria-hidden="true" class="c-button__icon c-button__icon--tertiary u-icon-m" fill="none" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="m17.9 16.5 5.1 5.1.7.7-1.4 1.4-.7-.7-5.1-5.1a9.7 9.7 0 0 1-6 2.1A9.6 9.6 0 0 1 1 10.5 9.6 9.6 0 0 1 10.5 1a9.6 9.6 0 0 1 9.5 9.5 9.7 9.7 0 0 1-2.1 6M10.5 3A7.6 7.6 0 0 0 3 10.5a7.6 7.6 0 0 0 7.5 7.5 7.6 7.6 0 0 0 7.5-7.5A7.6 7.6 0 0 0 10.5 3" fill="currentColor" fill-rule="evenodd"></path></svg></span></button><a class="c-button-template u-cursor-pointer c-button__container c-button--tertiary u-color-brand u-typography-h7 c-header__mobile-nav__item c-header__mobile-nav__favorites" href="//www.catawiki.com/en/veiling/favorites"><span class="c-button__overlay c-button__overlay--tertiary"></span><span class="c-button__content"><svg aria-hidden="true" class="c-button__icon c-button__icon--tertiary u-icon-m" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M18.4 1.1a6.7 6.7 0 0 0-6.3 2h-.2a6.7 6.7 0 0 0-6.3-2A6.9 6.9 0 0 0 .1 7 7.1 7.1 0 0 0 2 13l10 10 10-10a7.1 7.1 0 0 0 1.9-6 6.9 6.9 0 0 0-5.5-5.9m2.1 10.4L12 20l-8.6-8.4a4.9 4.9 0 0 1-1.3-4.4 5 5 0 0 1 3.8-4.1 4.9 4.9 0 0 1 5.3 2.2 1 1 0 0 0 1.6 0 5.1 5.1 0 0 1 5.3-2.2 4.9 4.9 0 0 1 3.8 4 4.8 4.8 0 0 1-1.4 4.4" fill="#03F"></path></svg></span></a><div class="u-flex u-flex--align-items-center"><a class="c-button-template u-cursor-pointer c-button__container c-button--tertiary u-color-brand u-typography-h7 c-header__mobile-nav__item js-sign-in-link js-user-menu-login-link" href="//www.catawiki.com/en/accounts/login"><span class="c-button__overlay c-button__overlay--tertiary"></span><span class="c-button__content"><svg aria-hidden="true" class="c-button__icon c-button__icon--tertiary u-icon-m" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M24 20c0-4-5-7-12-7S0 16 0 20v3h24zM2 21v-1c0-2 4-5 10-5s10 3 10 5v1zM12 1a5.5 5.5 0 1 0 0 11 5.5 5.5 0 1 0 0-11m0 9a3.5 3.5 0 1 1 0-7 3.5 3.5 0 0 1 0 7" fill="currentColor"></path></svg></span></a></div></div></div>
# <div class="c-header__search-form u-hide-m u-hide-l">
# <form action="" data-loaded="true" data-props='{"placeholder":"Search for brand, model, artist...","helpCenterPlaceholder":"Search for help articles...","auctionsHeading":"Related Auctions","collectionsHeading":"Related collections","recentSearchesHeading":"Recent searches","savedSearchesHeading":"Saved searches ","clearLabel":"Clear","undoLabel":"Undo","searchesClearedMessage":"Searches cleared","categoriesHeading":"Categories","manageSearchLabel":"Manage searches","signinToSeeSavedSearcesLabel":"&lt;a href=\"%{link}\"&gt;Sign in&lt;/a&gt; to see searches you saved"}' data-react-component-assets="Search"><div class="c-search-field"><div class="c-search-field__back-header"><button class="c-button-template u-cursor-pointer c-button__container c-button--tertiary u-color-primary u-typography-h7 c-search-field__back-button" data-testid="back-button" type="button"><span class="c-button__overlay c-button__overlay--tertiary"></span><span class="c-button__content"><svg aria-hidden="true" class="c-button__icon c-button__icon--tertiary u-icon-m" fill="none" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M13.59 6 15 7.41 10.42 12 15 16.59 13.59 18l-6-6z" fill="currentColor"></path></svg></span></button></div><div><div class="c-text-field c-text-field--normal c-search-field__field js-search-autocomplete"><div class="c-text-field__wrapper"><div class="c-text-field__prefix u-color-dark-gray u-cursor-pointer" data-testid="text-field-prefix"><button aria-label="Search" class="c-button-template u-cursor-pointer c-button__container c-button--tertiary u-color-brand u-typography-h7" type="button"><span class="c-button__overlay c-button__overlay--tertiary"></span><span class="c-button__content"><svg aria-hidden="true" class="c-button__icon c-button__icon--tertiary u-icon-m" fill="none" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="m17.9 16.5 5.1 5.1.7.7-1.4 1.4-.7-.7-5.1-5.1a9.7 9.7 0 0 1-6 2.1A9.6 9.6 0 0 1 1 10.5 9.6 9.6 0 0 1 10.5 1a9.6 9.6 0 0 1 9.5 9.5 9.7 9.7 0 0 1-2.1 6M10.5 3A7.6 7.6 0 0 0 3 10.5a7.6 7.6 0 0 0 7.5 7.5 7.6 7.6 0 0 0 7.5-7.5A7.6 7.6 0 0 0 10.5 3" fill="currentColor" fill-rule="evenodd"></path></svg></span></button></div><div class="c-text-field__input-wrapper label__wrapper"><input aria-expanded="false" aria-haspopup="listbox" autocapitalize="off" autocomplete="off" class="c-text-field__input c-search-field__input" data-auctions-heading="Related Auctions" data-testid="search-field" id="field:r5:" placeholder="Search for brand, model, artist..." role="combobox" type="search" value=""/></div></div></div></div></div></form>
# </div>
# <div class="c-header__with-sticky_search_input u-w-full u-hide-s u-hide-m u-hide-l">
# <form action="" data-loaded="true" data-props='{"placeholder":"Search for brand, model, artist..."}' data-react-component-assets="SearchInputStickyHeader"></form>
# </div>
# </div>
# </div>
# </header>
# <div id="old-browser-warning" style="display:none;">
# <div class="u-wrapper u-spacing-vertical-gutter">
# <p class="c-alert error">Catawiki is continuously updating its technology. You are currently using an outdated browser. To optimise your browsing experience, <a class="c-link primary" href="https://browsehappy.com" rel="noopener noreferrer">please update your browser.</a></p>
# </div>
# </div>
# <script>
#  if (!!document.documentMode) {
#  document.getElementById('old-browser-warning').style.display = 'block';
#  }
# </script>
# <div class="c-modal js-modal" data-nosnippet="" id="modal-cookies">
# <div class="c-modal__inner js-ab-new-cookie-flow-b">
# <h2 class="c-heading xl u-margin-b-small">Cookies</h2>
# <p>You can set your cookie preferences using the toggles below. You can update your preferences, withdraw your consent at any time, and see a detailed description of the types of cookies we and our partners use in our <a class="c-link" href="//www.catawiki.com/en/help/cookies">Cookie Policy</a>.</p>
# <div data-loaded="true" data-props="{&quot;marketingCookiesTitle&quot;:&quot;Marketing &amp; social media&quot;,&quot;marketingCookiesText&quot;:&quot;These cookies placed by Catawiki and partners help us gain insight into what you like and how you behave on our marketplace. We track your behaviour so we can get an idea about your preferences, store the IDs of the auctions you click on, and show you lots that match your interests. Third parties also place marketing cookies on Catawiki, including cookies to allow social media functionality.&quot;,&quot;analyticalCookiesTitle&quot;:&quot;Analytics &amp; research&quot;,&quot;analyticalCookiesText&quot;:&quot;These cookies placed by Catawiki and partners help us gain insight into the use of our marketplace and how to keep improving it.&quot;,&quot;functionalCookiesTitle&quot;:&quot;Functional&quot;,&quot;functionalCookiesText&quot;:&quot;These cookies are necessary for performance of our marketplace and are therefore set to 'always active'. This includes cookies to e.g. allow you to sign in and remember language settings. These cookies also include analytical cookies that have very little to no impact on your privacy.&quot;,&quot;moreInformation&quot;:&quot;More information&quot;,&quot;lessInformation&quot;:&quot;Show less&quot;,&quot;save&quot;:&quot;Save cookie settings&quot;}" data-react-component-assets="CookieForm"><div class="fe-cookie-form"><div class="fe-cookie-form__subsection"><hr class="c-horizontal-rule"/><h3 class="c-heading medium u-margin-b-small">Marketing &amp; social media</h3><div class="u-flex"><p class="u-color-secondary u-font-size-s u-margin-r-small">These cookies placed by Catawiki and partners help us gain insight into what you like and how you behave on our marketplace. We track your behaviour so we can get an idea about your preferences, store the IDs of the auctions you click on, and show you lots that match your interests. Third parties also place marketing cookies on Catawiki, including cookies to allow social media functionality.</p><div class="u-position-relative u-flex--inline"><input class="voLBejKbbRGFiZyGlUQ4 fGHBJycWuhzigSCXqqAo" id="marketing-cookies-toggle1" type="checkbox"/><label class="HvuEGhdNXWtCbacKBbPE" for="marketing-cookies-toggle1"><div aria-hidden="true" class="tKIRkDXYg9eQVGb9a3lE"></div></label></div></div><a class="u-font-size-s c-link primary no-underline fe-cookie-form__more-info">More information <svg class="u-icon-s" fill="none" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M10 6 8.59 7.41 13.17 12l-4.58 4.59L10 18l6-6z" fill="currentColor"></path></svg></a></div><div class="fe-cookie-form__subsection"><hr class="c-horizontal-rule"/><h3 class="c-heading medium u-margin-b-small">Analytics &amp; research</h3><div class="u-flex"><p class="u-color-secondary u-font-size-s u-margin-r-small">These cookies placed by Catawiki and partners help us gain insight into the use of our marketplace and how to keep improving it.</p><div class="u-position-relative u-flex--inline"><input class="voLBejKbbRGFiZyGlUQ4 fGHBJycWuhzigSCXqqAo" id="analytics-cookies-toggle2" type="checkbox"/><label class="HvuEGhdNXWtCbacKBbPE" for="analytics-cookies-toggle2"><div aria-hidden="true" class="tKIRkDXYg9eQVGb9a3lE"></div></label></div></div><a class="u-font-size-s c-link primary no-underline fe-cookie-form__more-info">More information <svg class="u-icon-s" fill="none" height="24" role="img" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M10 6 8.59 7.41 13.17 12l-4.58 4.59L10 18l6-6z" fill="currentColor"></path></svg></a></div><div class="fe-cookie-form__subsection"><hr class="c-horizontal-rule"/><h3 class="c-heading medium u-margin-b-small">Functional</h3><div class="u-flex"><p class="u-color-secondary u-font-size-s u-margin-r-small">These cookies are necessary for performance of our marketplace and are therefore set to 'always active'. This includes cookies to e.g. allow you to ...
# </div>
# </div>
# <div data-loaded="true" data-nosnippet="" data-props='{"terms":{"updatedTerms":"Updated Terms of Use","termsBody":"You’ll need to accept our new %{user_agreement} to keep buying and selling special objects.","termsBodyLinkText":"Terms of Use","accept":"Accept ","signout":"Sign out"},"legal":{"header":"We support buyers and sellers","body":"To continue buying and selling special objects, please confirm that you understand and agree Catawiki provides services for both buyers and sellers. %{learn_more}","learnMore":"Learn more","confirm":"Confirm","signout":"Sign out"}}' data-react-component-assets="TermsAndLegalAcceptance"><div class="fe-transparency-consent c-modal"><div class="c-modal__inner u-text-center"><div class="fe-transparency-consent__image"></div><h5 class="u-typography-h5 u-margin-t u-margin-b-small fe-transparency-consent__title">We support buyers and sellers</h5><p class="u-typography-body-s fe-transparency-consent__text">To continue buying and selling special objects, please confirm that you understand and agree Catawiki provides services for both buyers and sellers.  <a class="c-link primary no-underline" href="/en/help/about" rel="noreferrer" target="_blank">Learn more</a></p><div class="u-flex u-flex--direction-column u-m-t-m"><button class="c-button-template u-cursor-pointer c-button__container c-button--primary u-bgcolor-brand u-typography-h7 u-w-full"><span class="c-button__overlay c-button__overlay--primary"></span><span class="c-button__content"><span class="c-button__label c-button__label--primary">Confirm</span></span></button><button class="c-button-template u-cursor-pointer c-button__container c-button--tertiary u-color-dark-gray u-typography-h7 u-w-full u-m-t-s"><span class="c-button__overlay c-button__overlay--tertiary"></span><span class="c-button__content"><span class="c-button__label c-button__label--tertiary">Sign out</span></span></button></div></div></div><div class="fe-terms-acceptance c-modal"><div class="c-modal__inner u-text-center"><div class="fe-terms-acceptance__image"></div><h5 class="u-typography-h5 u-margin-t-large fe-terms-acceptance__title">Updated Terms of Use</h5><p class="u-typography-body-s fe-terms-acceptance__text">You’ll need to accept our new <a class="c-link primary no-underline" href="/en/pages/p/terms-of-use" rel="noreferrer" target="_blank">Terms of Use</a> to keep buying and selling special objects.</p><div class="u-flex u-flex--align-items-center u-m-t-m"><button class="c-button-template u-cursor-pointer c-button__container c-button--primary u-bgcolor-brand u-typography-h7 u-w-full"><span class="c-button__overlay c-button__overlay--primary"></span><span class="c-button__content"><span class="c-button__label c-button__label--primary">Accept </span></span></button><button class="c-button-template u-cursor-pointer c-button__container c-button--tertiary u-color-dark-gray u-typography-h7 u-w-full"><span class="c-button__overlay c-button__overlay--tertiary"></span><span class="c-button__content"><span class="c-button__label c-button__label--tertiary">Sign out</span></span></button></div></div></div></div>
# <div data-loaded="true" data-react-component-assets="SnackbarContainer"><div class="Toastify" id="c-snackbar"></div></div>
# <div class="sbr" data-loaded="true" data-props="{&quot;t&quot;:{&quot;email&quot;:&quot;Email address&quot;,&quot;googleButton&quot;:&quot;Continue with Google&quot;,&quot;continueWith&quot;:&quot;Continue with&quot;,&quot;facebookButton&quot;:&quot;Continue with Facebook&quot;,&quot;appleButton&quot;:&quot;Continue with Apple&quot;,&quot;login&quot;:&quot;Sign in&quot;,&quot;register&quot;:&quot;Register&quot;,&quot;loginWith&quot;:&quot;Sign in with&quot;,&quot;or&quot;:&quot;or&quot;,&quot;password&quot;:&quot;Password&quot;,&quot;registerButton&quot;:&quot;Create account&quot;,&quot;registerPlaceYourBidsHead&quot;:&quot;Place your bids on any of over 75,000 exceptional items auctioned every week&quot;,&quot;signInOrCreateAnAccount&quot;:&quot;Sign in or create an account&quot;,&quot;userPasswordLost&quot;:&quot;Forgotten your password?&quot;,&quot;userRememberMe&quot;:&quot;Remember me&quot;,&quot;welcomeBack&quot;:&quot;Welcome back!&quot;,&quot;enterNewPassword&quot;:&quot;Enter your new password&quot;,&quot;everyWeekObjectsAmount&quot;:&quot;Explore your passions and discover new ones. Over 75,000 new objects are added every week.&quot;,&quot;minPasswordRequirement&quot;:&quot;At least 8 characters, one capital letter, one lower case letter, one number and one special character&quot;,&quot;passwordResetLinkWillBeSent&quot;:&quot;We’ll email you a link to reset your password&quot;,&quot;passwordResetLinkSend&quot;:&quot;Send reset link&quot;,&quot;passwordResetLinkHasBeenSent&quot;:&quot;A link to reset your password was sent to %{email}&quot;,&quot;passwordValidationMinimalLength&quot;:&quot;Min 8 characters&quot;,&quot;passwordValidationDigitsAmount&quot;:&quot;Min one number&quot;,&quot;passwordValidationSpecialAmount&quot;:&quot;Min one special character&quot;,&quot;passwordValidationUpperAmount&quot;:&quot;Min one capital letter&quot;,&quot;passwordValidationLowerAmount&quot;:&quot;Min one lower case letter&quot;,&quot;firstName&quot;:&quot;First name&quot;,&quot;lastName&quot;:&quot;Last name&quot;,&quot;acceptConditions&quot;:&quot;By creating an account, you agree to our %{user_conditions} and acknowledge our %{privacy_policy}. Depending on how you use Catawiki, we may send you promotional emails. See our Privacy Policy for more info or to opt-out.&quot;,&quot;agreeAndContinue&quot;:&quot;Agree and continue&quot;,&quot;privacyPolicy&quot;:&quot;Privacy Policy&quot;,&quot;userAgreement&quot;:&quot;Terms of Use&quot;,&quot;generalError&quot;:&quot;Something went wrong, please try again later.&quot;,&quot;newPasswordNotCorrect&quot;:&quot;Make sure your new password is at least 8 characters and contains at least 1 number&quot;,&quot;required&quot;:&quot;This field is required&quot;,&quot;formIsInvalid&quot;:&quot;Please check and adjust your info.&quot;,&quot;userOnboardingUnsavedDataWarningMessage&quot;:&quot;Are you sure you want to exit? You can always log in and complete your profile later to start bidding. Press OK to exit.&quot;,&quot;maxCountCharacters&quot;:&quot;Max %{count} characters&quot;,&quot;enterYourHouseNumberOrFullStop&quot;:&quot;Enter your house number. If you don’t have one, enter a full stop (.)&quot;,&quot;back&quot;:&quot;Back&quot;,&quot;close&quot;:&quot;Close&quot;,&quot;open&quot;:&quot;Open&quot;,&quot;resetPassword&quot;:&quot;Reset your password&quot;,&quot;change&quot;:&quot;Change&quot;,&quot;country&quot;:&quot;Country&quot;,&quot;continue&quot;:&quot;Continue&quot;,&quot;phoneNumber&quot;:&quot;Phone number&quot;,&quot;countries&quot;:{&quot;ad&quot;:&quot;Andorra&quot;,&quot;at&quot;:&quot;Austria&quot;,&quot;be&quot;:&quot;Belgium&quot;,&quot;bg&quot;:&quot;Bulgaria&quot;,&quot;cn&quot;:&quot;China&quot;,&quot;cy&quot;:&quot;Cyprus&quot;,&quot;hr&quot;:&quot;Croatia&quot;,&quot;cz&quot;:&quot;Czech Republic&quot;,&quot;dk&quot;:&quot;Denmark&quot;,&quot;ee&quot;:&quot;Estonia&quot;,&quot;fi&quot;:&quot;Finland&quot;,&quot;fr&quot;:&quot;France&quot;,&quot;de&quot;:&quot;Germany&q ...
# <div data-loaded="true" data-react-component-assets="OutsideFlowFollower" id="sbrFlowFollwer"></div>
# <div class="favorites" data-loaded="true" data-props="{&quot;title&quot;:&quot;Find everything you’ve favourited, saved, and followed in My Favourites&quot;,&quot;description&quot;:&quot;We've updated the My Favourites page. Now you can view and find your saved searches, auctions, collections, and sellers you follow in one place. &quot;,&quot;go&quot;:&quot;Go to My Favourites&quot;,&quot;later&quot;:&quot;I'll do this later&quot;}" data-react-component-assets="MyFavorites"></div>
# ...
# <footer class="c-footer">
# <div data-loaded="true" data-react-component-assets="Authentication"><div class="u-p-v-m u-border-t-style-solid u-border-t-width-1 u-border-t-color-light-gray"><div class="u-wrapper u-flex u-flex--align-items-center"><button class="c-button-template u-cursor-pointer c-button__container c-button--primary u-bgcolor-brand u-typography-h7 u-m-r-m"><span class="c-button__overlay c-button__overlay--primary"></span><span class="c-button__content"><span class="c-button__label c-button__label--primary">Sign in</span></span></button><button class="c-button-template u-cursor-pointer c-button__container c-button--primary u-bgcolor-brand u-typography-h7"><span class="c-button__overlay c-button__overlay--primary"></span><span class="c-button__content"><span class="c-button__label c-button__label--primary">Register</span></span></button><div class="u-flex-1 u-text-right u-color-black u-hide-m u-hide-s"><div class="u-typography-h7">Bid on over 65,000 special objects every week, selected by 240+ experts</div></div></div></div></div>
# <section class="c-footer__main">
# <div class="u-wrapper" data-loaded="true" data-nosnippet="" data-props='{"settings":{"show_google_plus":true,"show_seller_info":true,"show_disclaimer_warning":false,"show_jobs_page":true,"show_press_page":true,"show_app_banner":true,"show_affiliate_page":true,"show_facebook":true,"show_collectors_platform":true,"show_category_guidelines":true},"hideSocial":null}' data-react-component-assets="MainFooter"><div class="u-wrapper"><div class="u-flex u-flex--justify-content-space-between u-flex--wrap u-g-xl"><div class="u-flex-1"><h6 class="u-typography-h6 u-color-title-text u-m-b-m">About Catawiki</h6><ul class="u-typography-h7"><li class="u-m-b-l u-m-t-l u-m-b-sm-l u-no-wrap"><a class="c-link no-underline u-color-tertiary" href="/en/help/about">About Catawiki</a></li><li class="u-m-b-l u-m-t-l u-m-b-sm-l u-no-wrap"><a class="c-link no-underline u-color-tertiary" href="/en/e">Our Experts</a></li><li class="u-m-b-l u-m-t-l u-m-b-sm-l u-no-wrap"><a class="c-link no-underline u-color-tertiary" href="https://catawiki.careers">Careers</a></li><li class="u-m-b-l u-m-t-l u-m-b-sm-l u-no-wrap"><a class="c-link no-underline u-color-tertiary" href="/en/press">Press</a></li><li class="u-m-b-l u-m-t-l u-m-b-sm-l u-no-wrap"><a class="c-link no-underline u-color-tertiary" href="/en/pages/p/partnership">Partnering with Catawiki</a></li><li class="u-m-b-l u-m-t-l u-m-b-sm-l u-no-wrap"><a class="c-link no-underline u-color-tertiary" href="https://www.lastdodo.com">Collectors' portal</a></li></ul></div><div class="u-flex-1"><h6 class="u-typography-h6 u-color-title-text u-m-b-m">Buy</h6><ul class="u-typography-h7"><li class="u-m-b-l u-m-t-l u-m-b-sm-l u-no-wrap"><a class="c-link no-underline u-color-tertiary" href="/en/pages/p/buyer">How to Buy</a></li><li class="u-m-b-l u-m-t-l u-m-b-sm-l u-no-wrap"><a class="c-link no-underline u-color-tertiary" href="/en/pages/p/buyer-protection">Buyer Protection</a></li><li class="u-m-b-l u-m-t-l u-m-b-sm-l u-no-wrap"><a class="c-link no-underline u-color-tertiary" href="/en/stories">Catawiki Stories</a></li><li class="u-m-b-l u-m-t-l u-m-b-sm-l u-no-wrap"><a class="c-link no-underline u-color-tertiary" href="/en/pages/p/buyer-terms">Buyer terms</a></li></ul></div><div class="u-flex-1"><h6 class="u-typography-h6 u-color-title-text u-m-b-m">Sell</h6><ul class="u-typography-h7"><li class="u-m-b-l u-m-t-l u-m-b-sm-l u-no-wrap"><a class="c-link no-underline u-color-tertiary" href="/en/seller/register">How to Sell</a></li><li class="u-m-b-l u-m-t-l u-m-b-sm-l u-no-wrap"><a class="c-link no-underline u-color-tertiary" href="/en/lp/seller-tips">Seller Tips</a></li><li class="u-m-b-l u-m-t-l u-m-b-sm-l u-no-wrap"><a class="c-link no-underline u-color-tertiary" href="/en/help/suitable-items">Submission guidelines</a></li><li class="u-m-b-l u-m-t-l u-m-b-sm-l u-no-wrap"><a class="c-link no-underline u-color-tertiary" href="/en/pages/p/seller-terms">Seller terms</a></li><li class="u-m-b-l u-m-t-l u-m-b-sm-l u-no-wrap"><a class="c-link no-underline u-color-tertiary" href="/en/affiliate">Affiliates</a></li></ul></div><div class="u-flex-1"><h6 class="u-typography-h6 u-color-title-text u-m-b-m">My Catawiki</h6><ul class="u-typography-h7"><li class="u-m-b-l u-m-t-l u-m-b-sm-l u-no-wrap"><a class="c-link">Sign in</a></li><li class="u-m-b-l u-m-t-l u-m-b-sm-l u-no-wrap"><a class="c-link">Register</a></li><li class="u-m-b-l u-m-t-l u-m-b-sm-l u-no-wrap"><a class="c-link no-underline u-color-tertiary" href="/en/help">Help Centre</a></li></ul></div></div><div class="u-flex u-flex--justify-content-space-between"><div class="mGCj1Mp20X3ulAINYV_e"><div class="c-dropdown u-typography-body" data-testid="dropdown-container"><div class="c-text-field c-text-field--normal"><div class="c-text-field__wrapper"><div class="c-text-field__input-wrapper label__wrapper"><input aria-expanded="false" aria-haspopup="listbox" class="c-text-field__input" id="field:rh:" placeholder="​" readonly="" role="combobox" type="text" value="English"/></div><div cla ...
# </section>
# <div data-loaded="true" data-react-component-assets="Imprint"><div class="u-wrapper"><div class="iGtQtg4AxB7ZMQ9k2jBC"><div class="IDKNrItS7KAoQtxMUifQ u-flex u-flex--justify-content-space-between u-typography-h7"><a class="c-link no-underline u-m-b-sm-xl" href="/en/pages/p/terms-of-use">Terms of Use </a><a class="c-link no-underline u-m-b-sm-xl" href="/en/help/buyer-terms/privacy-policy">Data Protection &amp; Privacy Notice</a><a class="c-link no-underline u-m-b-sm-xl" href="/en/help/cookies">Cookie Policy </a><a class="c-link no-underline u-m-b-sm-xl" href="/en/help/buyer-terms/guidelines-for-law-enforcement-requests">Law Enforcement Policy</a><a class="c-link no-underline u-m-b-sm-xl" href="/en/help/buyer-terms/responsible-disclosure-statement">Other Policies</a><div class="u-no-wrap">© 2024</div></div></div></div></div>
# </footer>
# <div data-loaded="true" data-nosnippet="" data-react-component-assets="ScrollToTop"><div class="c-scroll-to-top-button"><a aria-label="Scroll to top" class="c-scroll-to-top-button__link u-svg" href="#"><svg height="32" version="1.1" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg"><path d="M24.773 18.299c-0.651-0.669-7.512-7.203-7.512-7.203-0.349-0.357-0.805-0.536-1.261-0.536-0.458 0-0.914 0.179-1.261 0.536 0 0-6.861 6.534-7.514 7.203-0.651 0.669-0.696 1.872 0 2.586 0.698 0.712 1.669 0.77 2.522 0l6.253-5.995 6.251 5.995c0.854 0.77 1.827 0.712 2.522 0 0.698-0.715 0.654-1.918 0-2.586z"></path></svg></a></div></div>
# </div><div id="cw-js-container"><script>
#  window.AB={test:function(){return "A";},conversion:function(){}};
# </script>
# <script src="/ab/s.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="//cdn.catawiki.net/assets/shared-assets/ui/v2/application_nojquery-6922d32fb9b45752068b8424cd04c3a22cecf9b0407ab00a320511f9e0cb0114.js"></script>
# <script crossorigin="anonymous" defer="defer" src="//cdn.catawiki.net/assets/shared-assets/ui/v2/webpack/js/vendor.d6f14310c99d161e705a.js"></script>
# <script crossorigin="anonymous" defer="defer" src="//cdn.catawiki.net/assets/shared-assets/ui/v2/webpack/js/msHeader.d5c9a121de3dbaf13f1b.js"></script>
# </div></div></div><script id="__NEXT_DATA__" type="application/json">{"props":{"pageProps":{"assetData":{"header":"\u003c!-- Catawiki header --\u003e\n\u003cheader class='c-header'\u003e\n\u003cdiv class='c-header__main ab_snd_web_sticky_filters'\u003e\n\u003cdiv class='c-header__wrapper u-wrapper'\u003e\n\u003cdiv class='c-header__logo c-header__part-of-categories'\u003e\n\u003ca aria-label=\"homepage\" href=\"//www.catawiki.com/en/\"\u003e\u003cdiv class='c-header__logo__image c-header__logo__image__standard'\u003e\u003c/div\u003e\n\u003c/a\u003e\u003c/div\u003e\n\n\u003cdiv class='c-header__categories-popover c-header__part-of-categories' data-props='{\u0026quot;title\u0026quot;:\u0026quot;Categories\u0026quot;}' data-react-component-assets='CategoriesPopover'\u003e\u003c/div\u003e\n\n\u003cdiv class='c-header__search__main-wrapper c-header__part-of-categories'\u003e\n\u003cdiv class='c-header__search u-hide-print'\u003e\n\u003cform action='' data-props='{\u0026quot;placeholder\u0026quot;:\u0026quot;Search for brand, model, artist...\u0026quot;,\u0026quot;helpCenterPlaceholder\u0026quot;:\u0026quot;Search for help articles...\u0026quot;,\u0026quot;auctionsHeading\u0026quot;:\u0026quot;Related Auctions\u0026quot;,\u0026quot;collectionsHeading\u0026quot;:\u0026quot;Related collections\u0026quot;,\u0026quot;recentSearchesHeading\u0026quot;:\u0026quot;Recent searches\u0026quot;,\u0026quot;savedSearchesHeading\u0026quot;:\u0026quot;Saved searches \u0026quot;,\u0026quot;clearLabel\u0026quot;:\u0026quot;Clear\u0026quot;,\u0026quot;undoLabel\u0026quot;:\u0026quot;Undo\u0026quot;,\u0026quot;searchesClearedMessage\u0026quot;:\u0026quot;Searches cleared\u0026quot;,\u0026quot;categoriesHeading\u0026quot;:\u0026quot;Categories\u0026quot;,\u0026quot;manageSearchLabel\u0026quot;:\u0026quot;Manage searches\u0026quot;,\u0026quot;signinToSeeSavedSearcesLabel\u0026quot;:\u0026quot;\u0026lt;a href=\\\u0026quot;%{link}\\\u0026quot;\u0026gt;Sign in\u0026lt;/a\u0026gt; to see searches you saved\u0026quot;}' data-react-component-assets='Search'\u003e\u003c/form\u003e\n\u003c/div\u003e\n\n\u003c/div\u003e\n\u003cnav class='c-header__links c-header__part-of-categories u-hide-print'\u003e\n\u003cdiv class='c-header__links u-typography-h7 u-color-title-text'\u003e\n\u003cdiv class='c-header__links__sell u-hide-s'\u003e\n\u003cdiv class='c-header__links__normal-link'\u003e\n\u003ca class=\"header-sell c-link main no-underline\" href=\"//www.catawiki.com/en/seller/lot\"\u003eSell\u003c/a\u003e\n\u003c/div\u003e\n\u003c/div\u003e\n\u003cdiv class='c-header__links__guides u-hide-s'\u003e\n\u003cdiv class='c-header__links__normal-link'\u003e\n\u003ca class=\"c-link main no-underline\" href=\"//www.catawiki.com/en/help\"\u003eHelp\u003c/a\u003e\n\u003c/div\u003e\n\u003c/div\u003e\n\u003cdiv class='c-header__links__favourite u-hide-s'\u003e\n\u003ca aria-label=\"Favourites\" id=\"favourite-link-header\" href=\"//www.catawiki.com/en/veiling/favorites\"\u003e\u003csvg xmlns=\"http://www.w3.org/2000/svg\" width=\"24\" height=\"24\" viewBox=\"0 0 24 24\" class=\"u-svg\"\u003e\n \u003cpath fill=\"#03F\" d=\"M18.4 1.1c-2.306-.488-4.698.272-6.3 2h-.2c-1.602-1.728-3.994-2.488-6.3-2C2.688 1.679.473 4.055.1 7c-.336 2.187.366 4.405 1.9 6l10 10 10-10c1.534-1.595 2.236-3.813 1.9-6-.373-2.945-2.588-5.321-5.5-5.9zm2.1 10.4L12 20l-8.6-8.4c-1.136-1.16-1.622-2.809-1.3-4.4.313-2.013 1.816-3.635 3.8-4.1 2.056-.486 4.192.4 5.3 2.2.189.252.485.4.8.4.315 0 .611-.148.8-.4 1.147-1.752 3.25-2.624 5.3-2.2 1.968.426 3.476 2.012 3.8 4 .316 1.61-.212 3.269-1.4 4.4z\"\u003e\u003c/path\u003e\n\u003c/svg\u003e\n\n\u003c/a\u003e\u003c/div\u003e\n\u003cdiv class='u-hide-print u-hide-s'\u003e\n\u003cdiv data-props='{\u0026quot;isMobile\u0026quot;:false,\u0026quot;t\u0026quot;:{\u0026quot;dropdownTitle\u0026quot;:\u0026quot;Updates\u0026quot;,\u0026quot;emptyStateTitle\u0026quot;:\u0026quot;No updates\u0026quot;,\u0026quot;emptyStateBody\u0026quot;:\u0026quot;Check back soon for the latest upda ...
# case Date:d="; expires\x3d"+b.toUTCString()}document.cookie=encodeURIComponent(a)+"\x3d"+encodeURIComponent(f)+d+(c?"; domain\x3d"+c:"")+(e?"; path\x3d"+e:"")+(g?"; secure":"");return!0}};dataLayer.push({previousPageType:docCookies.getItem("previousPageType")});docCookies.setItem("previousPageType",google_tag_manager["rm"]["776266"](51),86400,"/")}catch(a){};</script><script id="" type="text/javascript">window._PXUZlkr2ZV={challenge:{context:{logoImgSrc:"https://cdn.catawiki.net/assets/marketing/ui/logos/Catawiki_Brandmark_Primary-9b07bd9af77f36a1dca6a4c4ee11953b010a73833b3cb3cdc2ea48b1ebd0866e.png"}}};window._pxOnCaptchaSuccess=function(a){a&&((a=document.querySelector(".js-register-signin-submit-button"))?a.click():location.reload())};var p=document.getElementsByTagName("script")[0],s=document.createElement("script");s.async=1;s.src="/UZlkr2ZV/init.js";p.parentNode.insertBefore(s,p);</script><div id="dialog-root"><div data-floating-ui-portal="" id=":r2:"></div><div data-floating-ui-portal="" id=":rb:"></div><div data-floating-ui-portal="" id=":re:"></div></div><div class="ReactModalPortal"></div></body></html>

# %%
def extractSellersStory(lot_soup):
    sellers_story = lot_soup.find_all("div",{"class":"lot-info-description__seller-profile-text"})[0]
    return sellers_story.text

# %%
class ExtractionException(Exception):

    def __init__(self, message, lot_soup):
        # Call the base class constructor with the parameters it needs
        super().__init__(message)
        self.lot_soup = lot_soup

def extractDescription(lot_soup):
    description_parent = lot_soup.find_all("div",{"class":"lot-info-description__description"})[0]
    children = description_parent.findChildren("p" , recursive=False)
    description = ""

    for child in children:
        description += "\n" + child.text

    if description is None:
        raise ExtractionException("Could not find item description",lot_soup)

    return description

# %%
description_parent = lot_soup.find_all("div",{"class":"lot-info-description__description"})[0]
children = description_parent.findChildren("p" , recursive=False)
description = ""

for child in children:
    description += child.get_text(separator="\n")

# %%
def getSellerStory(soup):
    sellers_story = soup.find_all("div", {"class": "lot-info-description__seller-profile-text"})[0]
    return sellers_story.get_text(separator="\n")

# %%
getSellerStory(lot_soup)
# Out:
# "Our family business has over 35 years of experience in jewellery, diamonds, watches, silver, precious metals, coins and banknotes.\n\nMany beautiful objects are offered to us through our more than 100 offices of Gold Exchange Office.\n\nBecause we are also active in Belgium and Germany as Gold Exchange Office, Comptoir de l'Or and Goldwechselhaus, we continuously have a new and varied range of top properties.\n\nWe are a member of the following trade associations: 'The Antwerp Exchange for Diamond Trade & NVMH (Dutch Association of Coin Traders)\n\nView our current offer on our supplier page!"

# %%
test_text = "Diamond - 0.48ct. - Brilliant - W-X, light yellow - SI2\nCut: Excellent\nPolish: Very Good\nSymmetry: Very Good\nFluorescence: Very Slight\nReport number: 532234282\nQuality: For your own impression, see photos.\nLot number 12-114672\nAll our items are shipped by registered mail.\nYou can also pick up the lot in one of our more than 100 offices in the Netherlands, Belgium or Germany.\nCheck the website of Goud Exchange Office (for NL and BE), Comptoir de l'Or (for BE) or Goldwechselhaus (for DE) for the nearest location.\nPlease let us know your preference via your Catawiki account."

# %%
Diamond - 0.48ct. - Brilliant - W-X, light yellow - SI2

Cut: Excellent
Polish: Very Good
Symmetry: Very Good
Fluorescence: Very Slight
Report number: 532234282

Quality: For your own impression, see photos.

Lot number 12-114672

All our items are shipped by registered mail.
You can also pick up the lot in one of our more than 100 offices in the Netherlands, Belgium or Germany.
Check the website of Goud Exchange Office (for NL and BE), Comptoir de l'Or (for BE) or Goldwechselhaus (for DE) for the nearest location.
Please let us know your preference via your Catawiki account.
